# %% [markdown]
# self localization

# %% [markdown]
# - feature point maps  -> SLAM
# - occupancy grid
# - quadtrees
# - point clouds

# %% [markdown]
# <a href="https://www.youtube.com/watch?v=yXCkyuo8bcs" target="_blank">
# <img src="https://img.youtube.com/vi/yXCkyuo8bcs/maxresdefault.jpg" alt="Computing Depth" width="250">
# </a>
